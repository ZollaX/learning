# %% [markdown]
# # Регистрация в Google-сервисах

# %% [markdown]
# Регистрация в google-сервисах.
#
# Для того чтобы мы могли пользоваться google-сервисами, необходимо зарегистрироваться в сервисе gmail (google-почта). Этот сервис станет вашей дверью
# во все остальные.
#
# Как создать аккаунт gmail?
#
# Для начала регистрации необходимо перейти по следующей ссылке:
# https://accounts.google.com/signup
#
#
#
#
#
# Прописали имя, далее общие сведения.
#
#
#
#
# Google Вам предложит на выбор подходящий для Вас адрес почты, но можно создать свой собственный
#
#
#  Создаем надежный пароль
#
#
# Обязательный этап - это резервные данные.
# Советуем внести резервный электронный ящик
#
#
#
# Теперь нажимаем на кнопку “Далее”, после этого перед вами появятся условия использования аккаунта google. Нужно внимательно их прочитать и нажать кнопку “Принимаю”:
#
#
#
#
#
# После этого мы перейдем на основную страницу нашего аккаунта. Если вы оказались на ней - значит успешно прошли все этапы регистрации.
#
#
# Для начала давайте попробуем зайти в сервис gmail (google-почта).
#
#
# Чтобы посмотреть список всех сервисов нужно нажать на такую вот кнопку в правом верхнем углу экрана:
#
# Примерно так будет выглядеть появившийся список сервисов:
