# %% [markdown]
# #**Начало работы**

# %% [markdown]
# Ниже ячейка с кодом для расчета суммы 1 + 2

# %%
1+4
# Out:
# 5

# %% [markdown]
# Ниже ячейка с кодом для расчета суммы последней строки

# %%
35-76
37+87
156+745
# Out:
# 901
