# %% [markdown]
# # Домашка

# %% [markdown]
# Установка библиотеки Python

# %%
# !pip install openai==1.6.1

# %% [markdown]
# Подключение ключа API

# %%
import openai
import os
from google.colab import userdata
key = userdata.get("Ключ")
os.environ["OPENAI_API_KEY"] = key

# %%
from openai import OpenAI
client = OpenAI()
stream = client.chat.completions.create(
    model="gpt-3.5-turbo-0125",
    messages=[{"role": "user", "content": "Say this is a test"}],
)
stream
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-bee4bcd59f1d> in <cell line: 1>()
# ----> 1 from openai import OpenAI
#       2 client = OpenAI()
#       3 stream = client.chat.completions.create(
#       4     model="gpt-3.5-turbo-0125",
#       5     messages=[{"role": "user", "content": "Say this is a test"}],
#
# ModuleNotFoundError: No module named 'openai'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
answer = stream.choices[0].message.content
answer
# Out:
# 'This is a test.'

# %%
stream = client.chat.completions.create(
    model="gpt-3.5-turbo-0125",
    messages=[{"role": "system", "content": "Ты высоко интеллектуальная машина с искуственным интеллектом"},
              {"role": "user", "content": "Что ты знаешь о переживаниях человека"}
              ],
)
answer = stream.choices[0].message.content
answer
# Out:
# 'Переживания человека являются его эмоциональными реакциями на окружающий мир, события и собственные мысли. Они могут включать различные состояния, такие как радость, грусть, страх, гнев, удивление и другие. Переживания могут быть вызваны различными факторами, такими как личные переживания, взаимодействия с другими людьми, событиями в жизни, а также состоянием здоровья и внешней средой. Переживания играют важную роль в жизни человека, помогая ему понимать и интерпретировать мир вокруг себя, а также общаться и взаимодействовать с другими людьми.'

# %%
from fastapi import FastAPI
from fastapi.responses import HTMLResponse
from pydantic import BaseModel
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-1f7cee4c6bb7> in <cell line: 1>()
# ----> 1 from fastapi import FastAPI
#       2 from fastapi.responses import HTMLResponse
#       3 from pydantic import BaseModel
#
# ModuleNotFoundError: No module named 'fastapi'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
